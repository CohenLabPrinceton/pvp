# %%
import numpy as np
import pylab as pl

from pvp.common.loggers import DataLogger
# Out:
# 2020-06-08 09:54:22,766 - pvp.common.prefs - INFO - Loaded prefs from /Users/ms81/pvp/prefs.json
# 2020-06-08 09:54:22,768 - pvp.common.prefs - INFO - Saved prefs to /Users/ms81/pvp/prefs.json

# %% [markdown]
# Get an instance of the data logger, and load a file

# %%
dl = DataLogger()
dff = dl.load_file("../../2020-06-04-15-54_controller_log.0.h5")  #PEEP5 PIP25 PID on dinkey
# Out:
# Reading... ../../2020-06-04-15-54_controller_log.0.h5

# %% [markdown]
# dff is adictionary. One can just extract waveform and control data

# %%
ls_wv = dff['waveform_data']
ls_ct = dff['control_data']

# %% [markdown]
# And plot it

# %%
data = np.zeros((len(ls_wv),2))
for idx in range(len(ls_wv)):
    data[idx,0] = ls_wv[idx][4]
    data[idx,1] = ls_wv[idx][3]

# %%
pl.plot(data[:,0] - np.min(data[:,0]), data[:,1])
pl.plot([0,40],[5,5],'k--')
pl.plot([0,40],[25,25],'k--')

pl.xlabel("time [s]")
pl.ylabel("pressure [cmH2O]");
